# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
import re
import string

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"<.*?>", "", text)
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = re.sub(r"\d+", "", text)
    return text

df["review_clean"] = df["review"].apply(clean_text)

# %%
df["review_clean"].isna().sum()
# Out:
# np.int64(0)

# %%
df = pd.read_csv("./data/IMDB Dataset.csv")

# %%
df.sample(5)
# Out:
#                                                   review sentiment
# 13218  The peculiar charisma of Martin Kosleck brings...  negative
# 29437  I saw this on a flight over to the U.S and was...  positive
# 2278   I like science-fiction movies and even, low-ra...  negative
# 23119  I know some people think the movie is boring b...  positive
# 27616  No artful writeup here because it doesn't dese...  negative

# %%
df.sentiment.value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
df.sample(5)
# Out:
#                                                   review sentiment
# 8367   I don't know how this movie has received so ma...  negative
# 6095   As with all the other reviewers, this movie ha...  positive
# 29564  In what attempts to be a positive story, Dolph...  negative
# 6375   So funny is the perfect way to describe this 1...  positive
# 15082  Along with "Aparadektoi, the best Greek Comedy...  positive

# %%
df_pos = df[df['sentiment']=='positive'][:5000]
df_neg = df[df['sentiment']=='negative'][:5000]

df_reviews = pd.concat([df_pos, df_neg ])

# %%
train,test = train_test_split(df_reviews,test_size =0.33,random_state=42)
train_x, train_y = train['review'], train['sentiment']
test_x, test_y = test['review'], test['sentiment']

# %%
train_y.value_counts()
# Out:
# sentiment
# negative    3378
# positive    3322
# Name: count, dtype: int64

# %%
tfidf = TfidfVectorizer(stop_words='english')
train_x_vector = tfidf.fit_transform(train_x)
test_x_vector = tfidf.transform(test_x)

# %%
train_x.shape
# Out:
# (6700,)

# %%
train_x_vector.shape
# Out:
# (6700, 44107)

# %%
type(train_x_vector)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
pd.DataFrame.sparse.from_spmatrix(train_x_vector,
                                  index=train_x.index,
                                  columns=tfidf.get_feature_names_out())
# Out:
#        00  000      10  100  101        11        12        13  13th  \
# 6746  NaN  NaN     NaN  NaN  NaN       NaN       NaN  0.444467   NaN
# 54    NaN  NaN     NaN  NaN  NaN  0.117455       NaN       NaN   NaN
# 8499  NaN  NaN     NaN  NaN  NaN       NaN       NaN       NaN   NaN
# 7869  NaN  NaN     NaN  NaN  NaN       NaN       NaN       NaN   NaN
# 3725  NaN  NaN  0.0764  NaN  NaN       NaN       NaN       NaN   NaN
# ...   ...  ...     ...  ...  ...       ...       ...       ...   ...
# 1501  NaN  NaN     NaN  NaN  NaN       NaN       NaN       NaN   NaN
# 358   NaN  NaN     NaN  NaN  NaN       NaN       NaN       NaN   NaN
# 761   NaN  NaN     NaN  NaN  NaN       NaN  0.091503       NaN   NaN
# 1685  NaN  NaN     NaN  NaN  NaN       NaN       NaN       NaN   NaN
# 4497  NaN  NaN     NaN  NaN  NaN       NaN       NaN       NaN   NaN
#
#             14  ...  young  younger  your  yourself  youth  zero  zoey  \
# 6746       NaN  ...    NaN      NaN   NaN       NaN    NaN   NaN   NaN
# 54         NaN  ...    NaN      NaN   NaN       NaN    NaN   NaN   NaN
# 8499  0.108228  ...    NaN      NaN   NaN       NaN    NaN   NaN   NaN
# 7869       NaN  ...    NaN      NaN   NaN       NaN    NaN   NaN   NaN
# 3725       NaN  ...    NaN      NaN   NaN       NaN    NaN   NaN   NaN
# ...        ...  ...    ...      ...   ...       ...    ...   ...   ...
# 1501       NaN  ...    NaN      NaN   NaN       NaN    NaN   NaN   NaN
# 358        NaN  ...    NaN      NaN   NaN       NaN    NaN   NaN   NaN
# 761        NaN  ...    NaN      NaN   NaN       NaN    NaN   NaN   NaN
# 1685       NaN  ...    NaN      NaN   NaN       NaN    NaN   NaN   NaN
# 4497       NaN  ...    NaN      NaN   NaN       NaN    NaN   NaN   NaN
#
#       zombie  zombies  zone
# 6746     NaN      NaN   NaN
# 54       NaN      NaN   NaN
# 8499     NaN      NaN   NaN
# 7869     NaN      NaN   NaN
# 3725     NaN      NaN   NaN
# ...      ...      ...   ...
# 1501     NaN      NaN   NaN
# 358      NaN      NaN   NaN
# 761      NaN      NaN   NaN
# 1685     NaN      NaN   NaN
# 4497     NaN      NaN   NaN
#
# [6700 rows x 5000 columns]

# %%
train_x.iloc[0]
# Out:
# "I happened to rent this movie with my sister in hopes of watching a great entertaining movie, that was humorous, however my expectations were let down. This movie was beyond disgusting and revolting for a PG-13 movie, this should have been rated R for the many mature references that went on in this movie. I wouldn't recommend allowing a 13 year old teen see this.<br /><br />Even if no one under the age of 17 is watching this movie, beware of a truly stupid movie, there's no humor in the movie, just a bunch of disgusting sexual references including a small touch of pedophilia, something that shouldn't even be joked about. <br /><br />I would like to know what happened to PG-13 movies, that were actually safe for actual a 13 year old? This is beyond a deplorable movie and should be re-rated."

# %%
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(df_reviews,test_size =0.33,random_state=42)

# %%
train_x, train_y = train['review'], train['sentiment']
test_x, test_y = test['review'], test['sentiment']

# %%
train_y.value_counts()
# Out:
# sentiment
# negative    3378
# positive    3322
# Name: count, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english')
train_x_vector = tfidf.fit_transform(train_x)
test_x_vector = tfidf.transform(test_x)

# %%
train_x.shape
# Out:
# (6700,)

# %%
train_x_vector.shape
# Out:
# (6700, 44107)

# %%
type(train_x_vector)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
primera_resenia = pd.DataFrame.sparse.from_spmatrix(train_x_vector,
                                  index=train_x.index,
                                  columns=tfidf.get_feature_names_out()).iloc[0]

# %%
primera_resenia
# Out:
# 00           NaN
# 000          NaN
# 007          NaN
# 00am         NaN
# 00s          NaN
#             ...
# ísnt         NaN
# île          NaN
# önsjön       NaN
# über         NaN
# überwoman    NaN
# Name: 6746, Length: 44107, dtype: Sparse[float64, nan]

# %%
train_x.iloc[0]
# Out:
# "I happened to rent this movie with my sister in hopes of watching a great entertaining movie, that was humorous, however my expectations were let down. This movie was beyond disgusting and revolting for a PG-13 movie, this should have been rated R for the many mature references that went on in this movie. I wouldn't recommend allowing a 13 year old teen see this.<br /><br />Even if no one under the age of 17 is watching this movie, beware of a truly stupid movie, there's no humor in the movie, just a bunch of disgusting sexual references including a small touch of pedophilia, something that shouldn't even be joked about. <br /><br />I would like to know what happened to PG-13 movies, that were actually safe for actual a 13 year old? This is beyond a deplorable movie and should be re-rated."

# %%
primera_resenia[primera_resenia != 0]
# Out:
# 00           NaN
# 000          NaN
# 007          NaN
# 00am         NaN
# 00s          NaN
#             ...
# ísnt         NaN
# île          NaN
# önsjön       NaN
# über         NaN
# überwoman    NaN
# Name: 6746, Length: 44107, dtype: Sparse[float64, nan]

# %%
train_x.iloc[0]
# Out:
# "I happened to rent this movie with my sister in hopes of watching a great entertaining movie, that was humorous, however my expectations were let down. This movie was beyond disgusting and revolting for a PG-13 movie, this should have been rated R for the many mature references that went on in this movie. I wouldn't recommend allowing a 13 year old teen see this.<br /><br />Even if no one under the age of 17 is watching this movie, beware of a truly stupid movie, there's no humor in the movie, just a bunch of disgusting sexual references including a small touch of pedophilia, something that shouldn't even be joked about. <br /><br />I would like to know what happened to PG-13 movies, that were actually safe for actual a 13 year old? This is beyond a deplorable movie and should be re-rated."

# %%
from sklearn.svm import SVC
svc = SVC(kernel='linear')
svc.fit(train_x_vector, train_y)
# Out:
# SVC(kernel='linear')

# %%
print(svc.predict(tfidf.transform(['A good movie'])))
print(svc.predict(tfidf.transform(['An excellent movie'])))
print(svc.predict(tfidf.transform(['I did not like this movie at all I gave this movie away'])))
# Out:
# ['positive']
# ['positive']
# ['negative']

# %%
print(svc.score(test_x_vector, test_y))
# Out:
# 0.8706060606060606

# %%
from sklearn.metrics import f1_score

f1_score(test_y,svc.predict(test_x_vector),
          labels = ['positive','negative'],average=None)
# Out:
# array([0.87400413, 0.86701962])

# %%
from sklearn.metrics import classification_report

print(classification_report(test_y,
                            svc.predict(test_x_vector),
                            labels = ['positive','negative']))
# Out:
#               precision    recall  f1-score   support
#
#     positive       0.87      0.88      0.87      1678
#     negative       0.88      0.86      0.87      1622
#
#     accuracy                           0.87      3300
#    macro avg       0.87      0.87      0.87      3300
# weighted avg       0.87      0.87      0.87      3300

# %%
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(test_y,
                           svc.predict(test_x_vector),
                           labels = ['positive', 'negative'])
conf_mat
# Out:
# array([[1481,  197],
#        [ 230, 1392]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
X_train_dense = train_x_vector.toarray()
X_test_dense = test_x_vector.toarray()

# %%
import re
import string

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"<.*?>", "", text)
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = re.sub(r"\d+", "", text)
    return text

df["review_clean"] = df["review"].apply(clean_text)

# %%
df["review_clean"].head()
# Out:
# 0    one of the other reviewers has mentioned that ...
# 1    a wonderful little production the filming tech...
# 2    i thought this was a wonderful way to spend ti...
# 3    basically theres a family where a little boy j...
# 4    petter matteis love in the time of money is a ...
# Name: review_clean, dtype: str

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df["review_clean"],
    df["sentiment"],
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features=5000)

train_x_vector = tfidf.fit_transform(X_train)
test_x_vector = tfidf.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(train_x_vector, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score, classification_report

y_pred = model.predict(test_x_vector)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8933
#               precision    recall  f1-score   support
#
#     negative       0.90      0.88      0.89      4961
#     positive       0.88      0.91      0.90      5039
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000

# %%
review = ["This movie was amazing and emotional"]
review_vec = tfidf.transform(review)

model.predict(review_vec)
# Out:
# array(['positive'], dtype=object)
